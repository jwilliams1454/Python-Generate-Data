# %%
# https://machinelearningmastery.com/generate-test-datasets-python-scikit-learn/

from sklearn.datasets import make_blobs
from matplotlib import pyplot
from pandas import DataFrame

# generate 2d classification dataset
X, y = make_blobs(n_samples=100, centers=3, n_features=2)

# scatter plot, dots colored by class value
df = DataFrame(dict(x=X[:,0], y=X[:,1], label=y))
colors = {0:'red', 1:'blue', 2:'green'}
fig, ax = pyplot.subplots()
grouped = df.groupby('label')
for key, group in grouped:
    group.plot(ax=ax, kind='scatter', x='x', y='y', label=key, color=colors[key])
pyplot.show()

# %%
from sklearn.datasets import make_blobs
from matplotlib import pyplot
from pandas import DataFrame

# generate 2d classification dataset
X, y = make_blobs(n_samples=100, centers=5, n_features=4)

# scatter plot, dots colored by class value
df = DataFrame(dict(x=X[:,0], y=X[:,1], label=y))
colors = {0:'red', 1:'blue', 2:'green', 3:'orange', 4:'violet'}
fig, ax = pyplot.subplots()
grouped = df.groupby('label')
for key, group in grouped:
    group.plot(ax=ax, kind='scatter', x='x', y='y', label=key, color=colors[key])
pyplot.show()

# %%
#

# generate 2d classification dataset
X, y = make_blobs(n_samples=100, centers=5, n_features=4, random_state=5)

# scatter plot, dots colored by class value
df = DataFrame(dict(x=X[:,0], y=X[:,1], label=y))
colors = {0:'red', 1:'blue', 2:'green', 3:'orange', 4:'violet'}
fig, ax = pyplot.subplots()
grouped = df.groupby('label')
for key, group in grouped:
    group.plot(ax=ax, kind='scatter', x='x', y='y', label=key, color=colors[key])
pyplot.show()

# %%
# New approach

#Load libraries
from sklearn.datasets import make_blobs
import matplotlib.pyplot as plt
import pandas as pd

# %%
# Generate data
features, clusters = make_blobs(n_samples = 2000,
                  n_features = 10, 
                  centers = 5,
                  cluster_std = 0.4,
                  shuffle = True)

# %%
# View
print("Feature Matrix: ");
print(pd.DataFrame(features, columns=["Feature 1", "Feature 2", "Feature 3",
         "Feature 4", "Feature 5", "Feature 6", "Feature 7", "Feature 8",
         "Feature 9", "Feature 10"]).head())
# Out:
# Feature Matrix:
#    Feature 1  Feature 2  Feature 3  Feature 4  Feature 5  Feature 6  \
# 0  -6.708976   6.250142   7.887034  -5.962568   6.192996   3.203854
# 1   9.076199   5.679878  -3.999800   6.645730   6.070707  -1.401305
# 2  -9.339160   3.465444  10.037988   2.517893  -1.294436  -3.685516
# 3   4.367409   4.020269   6.510475   7.235672  -6.782015   9.296398
# 4   9.743315   6.302906  -3.667916   7.582254   6.237564  -0.811134
#
#    Feature 7  Feature 8  Feature 9  Feature 10
# 0   8.993983   8.594414   9.901041    8.093948
# 1  10.564248   3.904874  -7.772678    1.696566
# 2   8.542394  -3.788456   5.648321    0.849314
# 3  -2.583065  -8.200628  -4.570266   -8.165033
# 4   9.802425   2.972906  -7.621940    1.363124

# %%
# Plot
plt.scatter(features[:,0], features[:,1])
plt.show()

# %%
# This looks good keep trying
# https://rdrr.io/github/elbamos/clusteringdatasets/man/make_blobs.html

make_blobs(n_samples = 100, n_features = 2, centers = 3,
  cluster_std = 1, center_box = c(-10, 10), shuffle = TRUE)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-22-a36a4f997963> in <module>
#       1 make_blobs(n_samples = 100, n_features = 2, centers = 3,
# ----> 2   cluster_std = 1, center_box = c(-10, 10), shuffle = TRUE)
#
# NameError: name 'c' is not defined

# %%
# Another way to make blobs
# http://cs.wellesley.edu/~dav/code/Week13-Clustering.html

# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn
from sklearn.datasets.samples_generator import make_blobs

# %%
X, y_true = make_blobs(n_samples=120, centers=4,
                       cluster_std=0.40, random_state=0)

print (X.shape)
print (y_true.shape)
# Out:
# (120, 2)
# (120,)

# %%
y_true
# Out:
# array([2, 3, 1, 0, 0, 1, 2, 2, 1, 1, 3, 0, 3, 3, 3, 0, 1, 2, 2, 0, 3, 3,
#        2, 0, 3, 2, 1, 2, 2, 3, 1, 0, 1, 0, 0, 1, 0, 0, 0, 1, 0, 1, 1, 2,
#        2, 0, 3, 3, 0, 0, 0, 3, 1, 1, 0, 3, 3, 3, 2, 1, 0, 0, 0, 1, 3, 1,
#        2, 3, 2, 2, 1, 2, 2, 0, 2, 1, 0, 2, 0, 1, 1, 1, 1, 1, 2, 1, 2, 0,
#        3, 2, 2, 2, 1, 1, 3, 1, 1, 0, 3, 0, 3, 3, 2, 1, 3, 0, 0, 3, 2, 2,
#        3, 3, 3, 3, 3, 2, 2, 0, 2, 3])

# %%
X[:10]
# Out:
# array([[-1.72611699,  3.68969508],
#        [-1.39592851,  7.73970834],
#        [ 2.21620418,  0.62373962],
#        [ 0.72254124,  4.15869086],
#        [ 0.96499719,  4.47512008],
#        [ 2.52677935,  0.82569373],
#        [-0.5736461 ,  3.29567406],
#        [-1.82480594,  2.58730685],
#        [ 1.58601816,  1.67511213],
#        [ 1.88981993,  0.59868174]])

# %%
plt.figure(figsize=(9,6))
plt.scatter(X[:, 0], X[:, 1], s=50); 
# s is the size of the dots in the plot

# %%
# Variation
# http://cs.wellesley.edu/~dav/code/Week13-Clustering.html
X, y_true = make_blobs(n_samples=120, centers=5,
                       cluster_std=0.80, random_state=10)

print (X.shape)
print (y_true.shape)
plt.figure(figsize=(9,6))
plt.scatter(X[:, 0], X[:, 1], s=50); 
# s is the size of the dots in the plot
# Out:
# (120, 2)
# (120,)

# %%
# Variation
X, y_true = make_blobs(n_samples=120, centers=5,
                       cluster_std=1.80, random_state=10)

print (X.shape)
print (y_true.shape)
plt.figure(figsize=(9,6))
plt.scatter(X[:, 0], X[:, 1], s=50); 
# s is the size of the dots in the plot
# Out:
# (120, 2)
# (120,)

# %%
# Yet another way

# matplotlib for ploting
from matplotlib import pyplot as plt 
from matplotlib import style

# %%
# Creating Test DataSets using sklearn.datasets.make_blobs
from sklearn.datasets.samples_generator import make_blobs
from matplotlib import pyplot as plt 
from matplotlib import style
  
style.use("fivethirtyeight")
  
X, y = make_blobs(n_samples = 100, centers = 3, 
               cluster_std = 1, n_features = 2)
  
plt.scatter(X[:, 0], X[:, 1], s = 40, color = 'g')
plt.xlabel("X")
plt.ylabel("Y")
  
plt.show()
plt.clf()

# %%
# Creating Test DataSets using sklearn.datasets.make_circles
from sklearn.datasets.samples_generator import make_circles
from matplotlib import pyplot as plt 
from matplotlib import style
  
style.use("fivethirtyeight")
  
X, y = make_circles(n_samples = 100, noise = 0.02)
plt.scatter(X[:, 0], X[:, 1], s = 40, color ='g')
plt.xlabel("X")
plt.ylabel("Y")
  
plt.show()
plt.clf()
